# %%
# Initialize variables
target_name = "ESTRELLA" 
SEED_NUM = 0            
redacted_name = ""

# Define vowels
vowels = "AEIOU"

# Process the string
for char in target_name:
    if char in vowels:
        redacted_name += str(SEED_NUM)
    else:
        redacted_name += char

# Output result
print(redacted_name)
# Out:
# 0STR0LL0

# %%
# Initialize engineer name
engineer_name = "ESTRELLA" 

# Extract first letter
first_letter = engineer_name[0]

# Convert to ASCII
ascii_value = ord(first_letter)

print("First Letter:", first_letter)
print("ASCII Value:", ascii_value)
# Out:
# First Letter: E
# ASCII Value: 69

# %%
verification_hash = (ascii_value * SEED_NUM) - loops

print("Verification Hash:", verification_hash)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 verification_hash = (ascii_value * SEED_NUM) - loops
#       3 print("Verification Hash:", verification_hash)
#
# NameError: name 'loops' is not defined

# %%
# [CELL 11} FOR LOOP
loops = SEED_NUM + 3
print(f"--- RUNNING {loops} CYCLES ---")

for i in range(1, loops + 1):
    print(f"Cycle{i}/{loops}... Complete")
# Out:
# --- RUNNING 3 CYCLES ---
# Cycle1/3... Complete
# Cycle2/3... Complete
# Cycle3/3... Complete

# %%
verification_hash = (ascii_value * SEED_NUM) - loops

print("Verification Hash:", verification_hash)
# Out:
# Verification Hash: -3

# %%
correct_password = "archangely"  # The password to check
attempts = 0                     # Counter for number of tries

while True:
    user_input = input("Enter password: ")
    attempts += 1
    
    if user_input == correct_password:
        print(f"Access granted! You got it in {attempts} attempt(s).")
        break  # Exit the loop
    else:
        print("Incorrect password, try again.")
# Out:
# Incorrect password, try again.
# Access granted! You got it in 2 attempt(s).
